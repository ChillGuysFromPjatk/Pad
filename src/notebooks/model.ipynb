# %%
import pandas as pd

df = pd.read_csv('cleaned/output_ebayspidercat_2_cleaned.csv')
df.head()
# Out:
#   condition            country model   sale_date  \
# 0   Używany  Stany Zjednoczone  Xbox  2024-12-29
# 1   Używany  Stany Zjednoczone  Xbox  2024-12-29
# 2   Używany  Stany Zjednoczone  Xbox  2024-12-29
# 3   Używany  Stany Zjednoczone  Xbox  2024-12-29
# 4   Używany  Stany Zjednoczone  Xbox  2024-12-29
#
#                                                title  price_pln   producer  \
# 0  Oryginalny pakiet konsoli Microsoft Xbox z kon...     327.48  Microsoft
# 1  Oryginalna konsola Microsoft OG Xbox tylko prz...     286.38  Microsoft
# 2  Oryginalny pakiet konsoli Microsoft Xbox z gra...     511.71  Microsoft
# 3  Oryginalny pakiet konsoli XBOX: (2) kontrolery...     532.18  Microsoft
# 4  Konsola Microsoft Xbox 8GB - czarna (Scarface ...     286.58  Microsoft
#
#   model_group  handheld  home_console  generation          seller_name  \
# 0        Xbox         0             1           6  galvearman.hqncmg46
# 1        Xbox         0             1           6      burrows.anton19
# ...

# %%
df_for_corr = df.drop(columns=['condition','country','model','sale_date','title','producer','model_group','seller_name', 'region'])
#IMO do ustalenia czy tych grup nie można jakoś zmapować - chociaż z drugiej strony dalej mamy 9 kolumn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df_for_corr.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    cbar=True,
    linewidths=0.5
)


plt.title("Macierz korelacji zmiennych z 'price_pln'", fontsize=16)
plt.show()
